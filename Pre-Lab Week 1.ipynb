# %% [markdown]
# # Pre-Lab

# %% [markdown]
# ## load library and import data

# %%
.libPaths('C:\\Program Files\\R\\R-3.6.1\\library')
library(SDSFoundations)
data <- BikeData

# %%
data
# Out:
#     user_id age gender student employed cyc_freq                distance time
# 1    1      28  M      1       1        Daily                    3.25    15
# 2    2      35  M      0       1        Daily                    1.11     5
# 3    3      28  M      0       1        Daily                    5.59    23
# 4    4      44  F      0       1        Less than once a month   3.24    24
# 5    5      42  M      0       1        Several times per week   7.81    26
# 6    6      36  M      0       1        Several times per week   3.00    20
# 7    7      45  M      0       1        Several times per week  13.03    51
# 8    8      54  M      0       1        Several times per week   6.21    39
# 9    9      39  M      0       1        Several times per week  13.95    50
# 10  10      44  M      0       0        Several times per month  7.40    44
# 11  11      29  M      0       1        Daily                    4.36    20
# ...

# %%
.libPaths()
# Out:
# [1] "C:/Program Files/R/R-3.6.1/library"
# [2] "C:/Users/sharifahmad/Anaconda3/Lib/R/library"

# %%
data$age[7]
# Out:
# [1] 45

# %%
data[7,2]
# Out:
# [1] 45

# %%
data[data$user_id==7,]
# Out:
#   user_id age gender student employed cyc_freq               distance time
# 7 7       45  M      0       1        Several times per week 13.03    51
#   speed
# 7 15.33

# %% [markdown]
# ## How many of the first 10 riders in the dataset ride daily

# %%
data[data$user_id<=10,]
# Out:
#    user_id age gender student employed cyc_freq                distance time
# 1   1      28  M      1       1        Daily                    3.25    15
# 2   2      35  M      0       1        Daily                    1.11     5
# 3   3      28  M      0       1        Daily                    5.59    23
# 4   4      44  F      0       1        Less than once a month   3.24    24
# 5   5      42  M      0       1        Several times per week   7.81    26
# 6   6      36  M      0       1        Several times per week   3.00    20
# 7   7      45  M      0       1        Several times per week  13.03    51
# 8   8      54  M      0       1        Several times per week   6.21    39
# 9   9      39  M      0       1        Several times per week  13.95    50
# 10 10      44  M      0       0        Several times per month  7.40    44
#    speed
# 1  13.00
# 2  13.32
# 3  14.58
# 4   8.10
# 5  18.02
# 6   9.00
# 7  15.33
# 8   9.55
# 9  16.74
# 10 10.09

# %%
table(data[data$user_id<=10,]$cyc_freq)
# Out:
#                   Daily  Less than once a month Several times per month
#                       3                       1                       1
#  Several times per week
#                       5

# %% [markdown]
# ## What is the speed of the first female who cycles less than one time per month (in miles/hour)

# %%
data[data$gender=='F',]
# Out:
#     user_id age gender student employed cyc_freq                distance time
# 4     4     44  F      0       1        Less than once a month   3.24    24
# 18   18     32  F      1       1        Daily                    9.34    40
# 21   21     51  F      0       1        Several times per week   3.40    21
# 24   24     30  F      0       1        Several times per week   4.89    19
# 27   27     27  F      0       1        Several times per week   0.87     6
# 29   29     27  F      0       1        Several times per week   3.09    22
# 36   36     29  F      0       1        Several times per month  4.72    20
# 37   37     33  F      0       1        Several times per week   2.32     7
# 38   38     29  F      0       1        Several times per month  9.35    35
# 46   46     32  F      0       1        Several times per month  9.39    36
# 47   47     36  F      0       1        Several times per month  9.09    18
# ...

# %%
temp <- data[data$gender=='F',]
temp[temp$cyc_freq=='Less than once a month',]
# Out:
#    user_id age gender student employed cyc_freq               distance time
# 4   4      44  F      0       1        Less than once a month 3.24     24
# 57 57      48  F      0       1        Less than once a month 4.44     18
#    speed
# 4   8.1
# 57 14.8

# %%
cond = (data$gender=='F')&(data$cyc_freq=="Less than once a month")
data[cond,]
# Out:
#    user_id age gender student employed cyc_freq               distance time
# 4   4      44  F      0       1        Less than once a month 3.24     24
# 57 57      48  F      0       1        Less than once a month 4.44     18
#    speed
# 4   8.1
# 57 14.8

# %%
cond
# Out:
#   [1] FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE
#  [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [121] FALSE

# %% [markdown]
# ## How many of the cyclists in the data frame were students?

# %%
data[data$student==1,]
# Out:
#     user_id age gender student employed cyc_freq               distance time
# 1     1     28  M      1       1        Daily                   3.25    15
# 15   15     26  M      1       1        Daily                  10.94    34
# 18   18     32  F      1       1        Daily                   9.34    40
# 31   31     25  M      1       1        Daily                   1.25     6
# 49   49     44  M      1       1        Several times per week  9.29    41
# 58   58     26  F      1       1        Daily                   2.77    16
# 59   59     44  M      1       1        Several times per week  4.84    22
# 77   77     63  M      1       1        Several times per week  6.56    40
# 86   86     22  M      1       0        Daily                   0.85     4
# 88   88     25  M      1       1        Several times per week  6.07    29
# 97   97     29  M      1       0        Several times per week  3.52    15
# ...

# %%
table(data$student)
# Out:
#   0   1
# 107  14

# %% [markdown]
# ## How often do they ride?

# %%
table(data[data$student==1,]$cyc_freq)
# Out:
#                   Daily  Less than once a month Several times per month
#                       8                       0                       0
#  Several times per week
#                       6

# %% [markdown]
# ## And what was the average distance that they rode?

# %%
mean(data[data$student==1,]$distance)
# Out:
# [1] 6.257857
