# %% [markdown]
# ## Load library

# %%
library(SDSFoundations, lib.loc = 'C:\\Program Files\\R\\R-3.6.1\\library')
wr = WorldRecords

# %% [markdown]
# # Primary Research Question
# How have the world record times for the men's and the women’s mile event changed over the years?

# %%
table(wr$Event)
# Out:
#       Mens 100m       Mens 800m       Mens Mile  Mens Polevault    Mens Shotput
#              17              24              32              55              39
# Mens TripleJump     Womens 100m     Womens 800m     Womens Mile  Womens Shotput
#              25              10              29              13              41

# %%
mm = wr[wr$Event == 'Mens Mile',]
wm = wr[wr$Event == 'Womens Mile',]

# %%
plot(mm$Year,mm$Record,main='mens mile , year vs record time',xlab='year',ylab='time')
plot(wm$Year,wm$Record,main='womens mile , year vs record time',xlab='year',ylab='time')
# Out:
# Plot with title "mens mile , year vs record time"
# Plot with title "womens mile , year vs record time"

# %%
linFit(mm$Year,mm$Record)
linFit(wm$Year,wm$Record)
# Out:
# Linear Fit
#  Intercept =  1007.471
#  Slope =  -0.39347
#  R-squared =  0.97746
# Plot with title "Linear"
# Linear Fit
#  Intercept =  2189.283
#  Slope =  -0.97288
#  R-squared =  0.89558
# Plot with title "Linear"
